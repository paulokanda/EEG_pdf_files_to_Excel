# %% [markdown]
# ![criança-EEG.gif](attachment:a0733d63-38b2-4149-af76-f7a6d0a2d37f.gif)

# %% [markdown]
# **Welcome to EEG Geeks!**
#
# If you're just starting to explore EEG—whether you're an undergraduate student, a junior postgraduate, or a student from related fields like psychology or other neurosciences—you’ve come to the right place! We're thrilled to have you here as we dive into the amazing world of electroencephalography.
#
# Our goal is to share knowledge, break down complex concepts, and help you understand and apply EEG in a practical and effective way. Together, we'll take it step by step, starting with the basics and gradually moving into more advanced topics.
#
# And of course, your **feedback, comments, and suggestions** are more than welcome! We want this space to be interactive and enriching, so don't hesitate to share your thoughts, questions, or ideas.
#
# Get ready to learn, get inspired, and fall even more in love with the incredible world of EEG. Shall we begin?
#
# **Welcome to EEG Geeks!** 🎉

# %% [markdown]
# ![1024-v1-0.png](attachment:a168c3c6-0ea9-4479-b465-0869b8d82b74.png)

# %% [raw]
# Hey EEG enthusiast! Welcome to EEG Geeks, your one-stop shop for all things EEG. To help us continue providing valuable content, please like and subscribe to our channel. Your support is greatly appreciated.
#
# "Get ready for some fun! We're about to embark on a little EEG experiment. I'll create a custom PDF template and collect EEG data in tables. Feel free to use any EEG acquisition software you're comfortable with. Let's see what we can discover!"
#
# Our goal is to find the most efficient way to extract tables from a PDF and transfer them into an Excel spreadsheet. I'll be working with Neurosoft's NeuroSpectrum software. The specific challenge is to accurately transfer the tabular data from the PDF into a structured Excel format. Firstly, I'll show you where things go wrong.
